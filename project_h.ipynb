# %%
# import library
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read file
df=pd.read_csv(r"C:\Users\Ankit\Desktop\amazon.csv")

# %%
# checking our data 
df.head(3)
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    NaN    your_email@gmail.com      04/01/19
# 1                    NaN    your_email@gmail.com      04/01/19
# 2                    NaN    your_email@gmail.com      04/01/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0             Your Name             1 YOUR STREET                        NaN
# 1             Your Name             1 YOUR STREET                        NaN
# 2             Your Name             1 YOUR STREET                        NaN
#
#    ... Order Status Carrier Name & Tracking Number Subtotal Shipping Charge  \
# ...

# %%
#counting our row and column
df.shape
# Out:
# (59, 23)

# %%
#cleaning data
#checking null 
df.isnull()
# Out:
#     Order Date  Order ID  Payment Instrument Type  Website  \
# 0        False     False                    False    False
# 1        False     False                    False    False
# 2        False     False                    False    False
# 3        False     False                    False    False
# 4        False     False                    False    False
# 5        False     False                    False    False
# 6        False     False                    False    False
# 7        False     False                    False    False
# 8        False     False                    False    False
# 9        False     False                    False    False
# 10       False     False                    False    False
# 11       False     False                    False    False
# 12       False     False                    False    False
# 13       False     False                    False    False
# 14       False     False                    False    False
# ...

# %%
#get total of null value by summing
df.isnull().sum()
# Out:
# Order Date                         0
# Order ID                           0
# Payment Instrument Type            0
# Website                            0
# Purchase Order Number             59
# Ordering Customer Email            0
# Shipment Date                      0
# Shipping Address Name              0
# Shipping Address Street 1          0
# Shipping Address Street 2         59
# Shipping Address City              0
# Shipping Address State             0
# Shipping Address Zip               0
# Order Status                       0
# Carrier Name & Tracking Number     0
# Subtotal                           0
# Shipping Charge                    0
# Tax Before Promotions              0
# Total Promotions                   0
# Tax Charged                        0
# Total Charged                      0
# Buyer Name                         0
# Group Name                        59
# dtype: int64

# %%
#fill all null value to 0
df = df.fillna(0)

# %%
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   04/04/19  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   04/05/19  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0    your_email@gmail.com      04/01/19
# 1                    0.0    your_email@gmail.com      04/01/19
# 2                    0.0    your_email@gmail.com      04/01/19
# 3                    0.0    your_email@gmail.com      04/05/19
# 4                    0.0    your_email@gmail.com      04/07/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0             Your Name             1 YOUR STREET                        0.0
# ...

# %%
#cheacking
df.isnull()
# Out:
#     Order Date  Order ID  Payment Instrument Type  Website  \
# 0        False     False                    False    False
# 1        False     False                    False    False
# 2        False     False                    False    False
# 3        False     False                    False    False
# 4        False     False                    False    False
# 5        False     False                    False    False
# 6        False     False                    False    False
# 7        False     False                    False    False
# 8        False     False                    False    False
# 9        False     False                    False    False
# 10       False     False                    False    False
# 11       False     False                    False    False
# 12       False     False                    False    False
# 13       False     False                    False    False
# 14       False     False                    False    False
# ...

# %%
# replace $ and str to floate 
# I did it two time that's why this error is showing
df["Total Charged"] = df["Total Charged"].str.replace('$','').astype(float)
# Out:
# <ipython-input-50-26dafe7395fc>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Total Charged"] = df["Total Charged"].str.replace('$','').astype(float)

# %%
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   04/04/19  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   04/05/19  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0    your_email@gmail.com      04/01/19
# 1                    0.0    your_email@gmail.com      04/01/19
# 2                    0.0    your_email@gmail.com      04/01/19
# 3                    0.0    your_email@gmail.com      04/05/19
# 4                    0.0    your_email@gmail.com      04/07/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0             Your Name             1 YOUR STREET                        0.0
# ...

# %%
#calculte the money spend on amazon
df['Total Charged'].sum()
# Out:
# 1777.7300000000002

# %%
#Avarage purchase on amazon
df['Total Charged'].mean()
# Out:
# 30.131016949152542

# %%
# finding median
df['Total Charged'].median()
# Out:
# 15.95

# %%
# high purchase on amazon
df['Total Charged'].max()
# Out:
# 210.99

# %%
# Minimum purchase
df['Total Charged'].min()
# Out:
# 1.04

# %%
# now we wants to do calculation for 'Tax charged' to now we should clean it than after we can do math on 'Tax Charged'
# cleaning 
df["Tax Charged"] = df["Tax Charged"].str.replace('$','').astype(float)
df.head()
# Out:
# <ipython-input-57-f47cff0b2b85>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Tax Charged"] = df["Tax Charged"].str.replace('$','').astype(float)
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   04/04/19  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   04/05/19  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0    your_email@gmail.com      04/01/19
# 1                    0.0    your_email@gmail.com      04/01/19
# ...

# %%
# find the total tax 
df['Tax Charged'].sum()
# Out:
# 52.60999999999999

# %%
# finding the total per iteam tax 
df['Tax Charged'].sum()/df['Total Charged'].sum()
# Out:
# 0.02959392033660904

# %%
# we have to set 'order date' type because there is order date is behaving as a string so we have to convert  
# so that computer read as a date 
df['Order Date']= pd.to_datetime(df['Order Date'])

# %%
#checking
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0 2019-04-01  112-0000000-0000001             Visa - 0001  Amazon.com
# 1 2019-04-01  112-0000000-0000002             Visa - 0001  Amazon.com
# 2 2019-04-01  112-0000000-0000003             Visa - 0001  Amazon.com
# 3 2019-04-04  112-0000000-0000004             Visa - 0001  Amazon.com
# 4 2019-04-05  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0    your_email@gmail.com      04/01/19
# 1                    0.0    your_email@gmail.com      04/01/19
# 2                    0.0    your_email@gmail.com      04/01/19
# 3                    0.0    your_email@gmail.com      04/05/19
# 4                    0.0    your_email@gmail.com      04/07/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0             Your Name             1 YOUR STREET                        0.0
# ...

# %%
# ploting bar graph to better visualling and analysis
df.plot.bar(x='Order Date', y='Total Charged')
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
# In the above figure there we having some diffcultes to view graph so that we set figure size
df.plot.bar(x='Order Date', y='Total Charged', figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
#So we have to analysis more efficent way. so we are grouping 'Order date' and sum 'Totel Charged'
daily_orders = df.groupby('Order Date').sum()["Total Charged"]
daily_orders.head()
# Out:
# Order Date
# 2019-04-01     63.91
# 2019-04-04    156.12
# 2019-04-05     27.64
# 2019-04-07     40.63
# 2019-04-08     44.99
# Name: Total Charged, dtype: float64

# %%
# ploting bar graph od daily_order so we can se efficly visulise
daily_orders.plot.bar(x='Order Date', y='Total Charged', figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='Order Date'>
